# %%
import requests
from bs4 import BeautifulSoup

globo_url = 'https://www.globo.com/'
page = requests.get(globo_url)

resposta = page.text

soup = BeautifulSoup(resposta, 'html.parser')

noticias = soup.find_all('h2', {'class': 'post__title'})

for i in range (len(noticias)):
    print(noticias[i].text)
# Out:
# STF terá estreia de Dino e pode discutir mudança nas aposentadorias
# 'Não há maioria no Congresso para reduzir emendas', diz novo líder do PT
# Vizinhos registram explosões em prédio; vídeo
# SP: imóvel com 3 mil munições é de coronel
# Veja o que se sabe sobre a morte de PM e da filha dele em SP
# Funcionária é afastada de delegacia após estupro
# Estados deixam de usar recursos para prevenir dengue
# Brasil ainda tem 1,2 mi em lares sem banheiro
# Facão, lona e comida: a casa na mata usada como esconderijo por foragidos
# Atirador esportivo é encontrado amarrado a carro; vídeo
# Qual é o segredo do rio chamado de 'arco-íris líquido'
# RJ: estudantes vencem desafio da Nasa
# Popó atropela e nocauteia Bambam em 36 segundos
# Nocaute agita a web e rende memes
# MC Gui nocauteia Nego do Borel, e confusão toma conta do ringue; vídeo
# Em harmonia, Fla e Flu duelam por soberania
# Hoje tem Fla x Flu! Veja times
# 'Rue Sócrates': ídolo do futebol brasileiro vai virar nome de rua na França
# Weverton ganha apoio, e Palmeiras deixa erro para trás: 'O melhor do Brasil'
# Resumo do BBB: festa tem desconfiança entre Davi e Isa e mais destaques
# Davi desconfia de aliada: 'Está jogando dos dois lados'
# Fernanda narra conversa: 'Estava bem antes de você chegar'
# Poder Curinga, poder do Anjo e mais: como fica a formação do Paredão
# Fernanda quer mandar brother
# Alane diz sentir 'pena' de brother na casa: 'Ele fica muito sozinho'
# 'Bin não parece artista', fala Rodriguinho sobre brother
# Pai e três filhos que morreram em acidente em rodovia são enterrados em SP
# A equipe que disputa prêmio de US$ 5 milhões para 'desvendar' florestas
# Família entra na Justiça e consegue remédio milionário para salvar criança com doença rara
# Ex-pastor deixa pregação e passa a vender conteúdo adulto com a parceira na internet
# Veneno de aranha brasileira vira esperança de tratamento contra câncer
# Conheça as galinhas gigantes de R$ 5mil que produzem ovos com custo de R$ 400 a dúzia
# Professora deixa carreira, abre curso de criação de álbuns fotográficos e lucra mais de R$ 500 mil
# 'Fui a Antártica e ouvi o silêncio do fim do mundo': o relato de uma influenciadora
# A evolução do corpo de CR7: veja hábitos que ajudam o astro a manter a forma
